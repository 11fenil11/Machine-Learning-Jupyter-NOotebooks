# %%
import pandas as pd
pd.__version__
# Out:
# '0.25.1'

# %%
df = pd.read_csv("C:\\Users\\Fenil\\Pandas-Tutorial-master\\RegularSeasonCompactResults.csv")
df
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0         1985      20   1228      81   1328      64    N      0
# 1         1985      25   1106      77   1354      70    H      0
# 2         1985      25   1112      63   1223      56    H      0
# 3         1985      25   1165      70   1432      54    H      0
# 4         1985      25   1192      86   1447      74    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0
#
# [145289 rows x 8 columns]

# %%
df.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0

# %%
df.tail()
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0

# %%
df.shape
# Out:
# (145289, 8)

# %%
df.columns.tolist()
# Out:
# ['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc', 'Numot']

# %%
df.columns
# Out:
# Index(['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc',
#        'Numot'],
#       dtype='object')

# %%
#df.index.tolist()

# %%
df.index
# Out:
# RangeIndex(start=0, stop=145289, step=1)

# %%
df.max()
# Out:
# Season    2016
# Daynum     132
# Wteam     1464
# Wscore     186
# Lteam     1464
# Lscore     150
# Wloc         N
# Numot        6
# dtype: object

# %%
df.columns
# Out:
# Index(['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc',
#        'Numot'],
#       dtype='object')

# %%
df['Season']# df.Season
# Out:
# 0         1985
# 1         1985
# 2         1985
# 3         1985
# 4         1985
#           ...
# 145284    2016
# 145285    2016
# 145286    2016
# 145287    2016
# 145288    2016
# Name: Season, Length: 145289, dtype: int64

# %%
df[['Season','Wteam','Lscore']]
# Out:
#         Season  Wteam  Lscore
# 0         1985   1228      64
# 1         1985   1106      70
# 2         1985   1112      56
# 3         1985   1165      54
# 4         1985   1192      74
# ...        ...    ...     ...
# 145284    2016   1114      50
# 145285    2016   1163      58
# 145286    2016   1246      77
# 145287    2016   1277      62
# 145288    2016   1386      74
#
# [145289 rows x 3 columns]

# %%
df['Lscore'].max()
# Out:
# 150

# %%
df['Lscore'].mean()
# Out:
# 64.49700940883343

# %%
df.describe()
# Out:
#               Season         Daynum          Wteam         Wscore  \
# count  145289.000000  145289.000000  145289.000000  145289.000000
# mean     2001.574834      75.223816    1286.720646      76.600321
# std         9.233342      33.287418     104.570275      12.173033
# min      1985.000000       0.000000    1101.000000      34.000000
# 25%      1994.000000      47.000000    1198.000000      68.000000
# 50%      2002.000000      78.000000    1284.000000      76.000000
# 75%      2010.000000     103.000000    1379.000000      84.000000
# max      2016.000000     132.000000    1464.000000     186.000000
#
#                Lteam         Lscore          Numot
# count  145289.000000  145289.000000  145289.000000
# mean     1282.864064      64.497009       0.044387
# std       104.829234      11.380625       0.247819
# min      1101.000000      20.000000       0.000000
# 25%      1191.000000      57.000000       0.000000
# 50%      1280.000000      64.000000       0.000000
# ...

# %%
#SQL Like Querry
df[df.Season>2002]
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 74048     2003      10   1104      68   1328      62    N      0
# 74049     2003      10   1272      70   1393      63    N      0
# 74050     2003      11   1266      73   1437      61    N      0
# 74051     2003      11   1296      56   1457      50    N      0
# 74052     2003      11   1400      77   1208      71    N      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0
#
# [71241 rows x 8 columns]

# %%
print(df.Wscore.max())
print(df['Wscore'].max())
# Out:
# 186
# 186

# %%
df[df.Wscore==df['Wscore'].max()] #Give a row when Winning team's score is max
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 24970    1991      68   1258     186   1109     140    H      0

# %%
df[['Lscore','Season']][df.Wscore==df['Wscore'].max()] #Only give Lscore and Season while winning team's score was max
# Out:
#        Lscore  Season
# 24970     140    1991

# %%
df.index
# Out:
# RangeIndex(start=0, stop=145289, step=1)

# %%
df
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0         1985      20   1228      81   1328      64    N      0
# 1         1985      25   1106      77   1354      70    H      0
# 2         1985      25   1112      63   1223      56    H      0
# 3         1985      25   1165      70   1432      54    H      0
# 4         1985      25   1192      86   1447      74    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0
#
# [145289 rows x 8 columns]

# %%
df.set_index('Season',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-33b730a29a0c> in <module>
# ----> 1 df.set_index('Season',inplace=True)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['Season'] are in the columns"

# %%
df
# Out:
#         Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# Season
# 1985        20   1228      81   1328      64    N      0
# 1985        25   1106      77   1354      70    H      0
# 1985        25   1112      63   1223      56    H      0
# 1985        25   1165      70   1432      54    H      0
# 1985        25   1192      86   1447      74    H      0
# ...        ...    ...     ...    ...     ...  ...    ...
# 2016       132   1114      70   1419      50    N      0
# 2016       132   1163      72   1272      58    N      0
# 2016       132   1246      82   1401      77    N      1
# 2016       132   1277      66   1345      62    N      0
# 2016       132   1386      87   1433      74    N      0
#
# [145289 rows x 7 columns]

# %%
df.loc['2016']
# Out:
#         Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# Season
# 2016        11   1104      77   1244      64    H      0
# 2016        11   1105      68   1408      67    A      1
# 2016        11   1112      79   1334      61    H      0
# 2016        11   1115      58   1370      56    A      0
# 2016        11   1116      86   1380      68    H      0
# ...        ...    ...     ...    ...     ...  ...    ...
# 2016       132   1114      70   1419      50    N      0
# 2016       132   1163      72   1272      58    N      0
# 2016       132   1246      82   1401      77    N      1
# 2016       132   1277      66   1345      62    N      0
# 2016       132   1386      87   1433      74    N      0
#
# [5369 rows x 7 columns]

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0         1985      20   1228      81   1328      64    N      0
# 1         1985      25   1106      77   1354      70    H      0
# 2         1985      25   1112      63   1223      56    H      0
# 3         1985      25   1165      70   1432      54    H      0
# 4         1985      25   1192      86   1447      74    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0
#
# [145289 rows x 8 columns]

# %%
df.loc[10000]
# Out:
# Season    1987
# Daynum      96
# Wteam     1379
# Wscore      71
# Lteam     1376
# Lscore      57
# Wloc         H
# Numot        0
# Name: 10000, dtype: object

# %%
import numpy
df.iloc[[df['Wscore'].argmax()]]
# Out:
# C:\Users\Fenil\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 24970    1991      68   1258     186   1109     140    H      0

# %%
df.iloc[[df['Wscore'].idxmax()]]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 24970    1991      68   1258     186   1109     140    H      0
