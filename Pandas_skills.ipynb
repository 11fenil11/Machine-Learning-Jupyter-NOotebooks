# %%
import pandas as pd

# %%
df = pd.read_table('https://bit.ly/chiporders')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
ds = pd.read_table('https://bit.ly/movieusers')
ds
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# ..                            ...
# 937        939|26|F|student|33319
# 938  940|32|M|administrator|02215
# 939        941|20|M|student|97229
# 940      942|48|F|librarian|78209
# 941        943|22|M|student|77841
#
# [942 rows x 1 columns]

# %%
ds = pd.read_table('https://bit.ly/movieusers',sep='|',header=None)
ds
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# ..   ...  .. ..            ...    ...
# 938  939  26  F        student  33319
# 939  940  32  M  administrator  02215
# 940  941  20  M        student  97229
# 941  942  48  F      librarian  78209
# 942  943  22  M        student  77841
#
# [943 rows x 5 columns]

# %%
cols_names=['Us_id','Age','Gender','Occupation','Zip_code']
ds = pd.read_table('https://bit.ly/movieusers',sep='|',header=None,names=cols_names)
ds
# Out:
#      Us_id  Age Gender     Occupation Zip_code
# 0        1   24      M     technician    85711
# 1        2   53      F          other    94043
# 2        3   23      M         writer    32067
# 3        4   24      M     technician    43537
# 4        5   33      F          other    15213
# ..     ...  ...    ...            ...      ...
# 938    939   26      F        student    33319
# 939    940   32      M  administrator    02215
# 940    941   20      M        student    97229
# 941    942   48      F      librarian    78209
# 942    943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
ds.describe()
# Out:
#             Us_id         Age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
ds.Occupation + ', ' + ds.Zip_code
# Out:
# 0         technician, 85711
# 1              other, 94043
# 2             writer, 32067
# 3         technician, 43537
# 4              other, 15213
#                ...
# 938          student, 33319
# 939    administrator, 02215
# 940          student, 97229
# 941        librarian, 78209
# 942          student, 77841
# Length: 943, dtype: object

# %%
ds['New']=ds.Occupation + ', ' + ds.Zip_code

# %%
ds
# Out:
#      Us_id  Age Gender     Occupation Zip_code                   New
# 0        1   24      M     technician    85711     technician, 85711
# 1        2   53      F          other    94043          other, 94043
# 2        3   23      M         writer    32067         writer, 32067
# 3        4   24      M     technician    43537     technician, 43537
# 4        5   33      F          other    15213          other, 15213
# ..     ...  ...    ...            ...      ...                   ...
# 938    939   26      F        student    33319        student, 33319
# 939    940   32      M  administrator    02215  administrator, 02215
# 940    941   20      M        student    97229        student, 97229
# 941    942   48      F      librarian    78209      librarian, 78209
# 942    943   22      M        student    77841        student, 77841
#
# [943 rows x 6 columns]

# %%
movies = pd.read_csv('https://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.describe(include=['object'])
# Out:
#                                   title content_rating  genre  \
# count                               979            976    979
# unique                              975             12     16
# top     The Girl with the Dragon Tattoo              R  Drama
# freq                                  2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
movies.shape
# Out:
# (979, 6)

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo = pd.read_csv('https://bit.ly/uforeports')
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %% [markdown]
# # Rename Column

# %%
ufo.rename(columns = {'City':'CITY','State':'STATE'},inplace = True)
ufo
# Out:
#                        CITY Colors Reported Shape Reported STATE  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo_cols=['city','colors reported','Shape Reported','state','time']

# %%
ufo.columns = ufo_cols

# %%
ufo.head()
# Out:
#                    city colors reported Shape Reported state             time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.columns = ufo.columns.str.replace(' ','__')

# %%
ufo.columns
# Out:
# Index(['city', 'colors__reported', 'Shape__Reported', 'state', 'time'], dtype='object')

# %% [markdown]
# ## Removing Column (AXIS=1)

# %%
ufo.drop('city',axis=1,inplace=True)
ufo.head()
# Out:
#   colors__reported Shape__Reported state             time
# 0              NaN        TRIANGLE    NY   6/1/1930 22:00
# 1              NaN           OTHER    NJ  6/30/1930 20:00
# 2              NaN            OVAL    CO  2/15/1931 14:00
# 3              NaN            DISK    KS   6/1/1931 13:00
# 4              NaN           LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# # Removing Raw(Axis=0)

# %%
ufo
# Out:
#       colors__reported Shape__Reported state              time
# 0                  NaN        TRIANGLE    NY    6/1/1930 22:00
# 1                  NaN           OTHER    NJ   6/30/1930 20:00
# 2                  NaN            OVAL    CO   2/15/1931 14:00
# 3                  NaN            DISK    KS    6/1/1931 13:00
# 4                  NaN           LIGHT    NY   4/18/1933 19:00
# ...                ...             ...   ...               ...
# 18236              NaN        TRIANGLE    IL  12/31/2000 23:00
# 18237              NaN            DISK    IA  12/31/2000 23:00
# 18238              NaN             NaN    WI  12/31/2000 23:45
# 18239              RED           LIGHT    WI  12/31/2000 23:45
# 18240              NaN            OVAL    FL  12/31/2000 23:59
#
# [18241 rows x 4 columns]

# %%
ufo.drop([1,2],axis=0,inplace=True)
ufo.head()
# Out:
#   colors__reported Shape__Reported state             time
# 0              NaN        TRIANGLE    NY   6/1/1930 22:00
# 3              NaN            DISK    KS   6/1/1931 13:00
# 4              NaN           LIGHT    NY  4/18/1933 19:00
# 5              NaN            DISK    ND  9/15/1934 15:30
# 6              NaN          CIRCLE    CA   6/15/1935 0:00

# %% [markdown]
# # Sort Datafram or Series

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %% [markdown]
# # Sorting

# %%
movies.title.sort_values()#movies['title'].sort_values()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
movies.sort_values('star_rating')
# Out:
#      star_rating                           title content_rating    genre  \
# 978          7.4                     Wall Street              R    Crime
# 950          7.4                           Bound              R    Crime
# 949          7.4                      Home Alone             PG   Comedy
# 948          7.4                      Frances Ha              R   Comedy
# 947          7.4                      Eraserhead        UNRATED    Drama
# ..           ...                             ...            ...      ...
# 6            8.9  The Good, the Bad and the Ugly      NOT RATED  Western
# 3            9.0                 The Dark Knight          PG-13   Action
# 2            9.1          The Godfather: Part II              R    Crime
# 1            9.2                   The Godfather              R    Crime
# 0            9.3        The Shawshank Redemption              R    Crime
#
#      duration                                        actors_list
# ...

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies.sort_values('star_rating',ascending=False)
# Out:
#      star_rating                     title content_rating   genre  duration  \
# 0            9.3  The Shawshank Redemption              R   Crime       142
# 1            9.2             The Godfather              R   Crime       175
# 2            9.1    The Godfather: Part II              R   Crime       200
# 3            9.0           The Dark Knight          PG-13  Action       152
# 4            8.9              Pulp Fiction              R   Crime       154
# ..           ...                       ...            ...     ...       ...
# 948          7.4                Frances Ha              R  Comedy        86
# 949          7.4                Home Alone             PG  Comedy       103
# 950          7.4                     Bound              R   Crime       108
# 951          7.4             Sleepy Hollow              R   Drama       105
# 978          7.4               Wall Street              R   Crime       126
#
#                                            actors_list
# ...

# %% [markdown]
# ## Sorting by multiple columns

# %%
movies.sort_values(['star_rating','duration'])
# Out:
#      star_rating                                          title  \
# 938          7.4                            Alice in Wonderland
# 948          7.4                                     Frances Ha
# 966          7.4                             The Simpsons Movie
# 947          7.4                                     Eraserhead
# 971          7.4                             Death at a Funeral
# ..           ...                                            ...
# 7            8.9  The Lord of the Rings: The Return of the King
# 3            9.0                                The Dark Knight
# 2            9.1                         The Godfather: Part II
# 1            9.2                                  The Godfather
# 0            9.3                       The Shawshank Redemption
#
#     content_rating      genre  duration  \
# 938              G  Animation        75
# 948              R     Comedy        86
# 966          PG-13  Animation        87
# ...

# %%
movies[movies.duration>200]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...

# %% [markdown]
# ## Multiple Filter Criteria

# %%
movies[(movies.duration > 200) & (movies.genre =='Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
movies[(movies.genre == 'Crime') | (movies.genre == 'Drama') | (movies.genre == 'Action')]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %% [markdown]
# # isin()

# %%
movies.genre.isin(['Crime','Drama','Action'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 974    False
# 975    False
# 976     True
# 977    False
# 978     True
# Name: genre, Length: 979, dtype: bool

# %%
movies[movies.genre.isin(['Crime','Drama','Action'])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %% [markdown]
# # Read only numeric column

# %%
import numpy as np
movies.select_dtypes(include=[np.number])
# Out:
#      star_rating  duration
# 0            9.3       142
# 1            9.2       175
# 2            9.1       200
# 3            9.0       152
# 4            8.9       154
# ..           ...       ...
# 974          7.4       116
# 975          7.4       118
# 976          7.4       138
# 977          7.4       114
# 978          7.4       126
#
# [979 rows x 2 columns]

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
drinks = pd.read_csv('https://bit.ly/drinksbycountry')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %% [markdown]
# # Axis Parameter

# %%
drinks.mean()
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %% [markdown]
# ## Top to Bottom Collaps (Axis=0 for Specific Row)

# %%
drinks.mean(axis=0)
# drinks.mean(axis='index')
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.mean(axis=0).shape
# Out:
# (4,)

# %% [markdown]
# ## Left to right Collaps(Axis =1 for specific Column)

# %%
drinks.mean(axis=1)
#drinks.mean(axis='column')
# Out:
# 0        0.000
# 1       69.975
# 2        9.925
# 3      176.850
# 4       81.225
#         ...
# 188    110.925
# 189     29.000
# 190      1.525
# 191     14.375
# 192     22.675
# Length: 193, dtype: float64

# %%
drinks.mean(axis=1).shape
# Out:
# (193,)

# %% [markdown]
# # String Methods in pandas

# %%
'hello'.upper()
# Out:
# 'HELLO'

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.item_name.str.upper()
# Out:
# 0                CHIPS AND FRESH TOMATO SALSA
# 1                                        IZZE
# 2                            NANTUCKET NECTAR
# 3       CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                                CHICKEN BOWL
#                         ...
# 4617                            STEAK BURRITO
# 4618                            STEAK BURRITO
# 4619                       CHICKEN SALAD BOWL
# 4620                       CHICKEN SALAD BOWL
# 4621                       CHICKEN SALAD BOWL
# Name: item_name, Length: 4622, dtype: object

# %%
df.item_name.str.contains('Chicken')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4617    False
# 4618    False
# 4619     True
# 4620     True
# 4621     True
# Name: item_name, Length: 4622, dtype: bool

# %%
df[df.item_name.str.contains('Chicken')]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4615      1832         1    Chicken Soft Tacos
# 4619      1834         1    Chicken Salad Bowl
# 4620      1834         1    Chicken Salad Bowl
# 4621      1834         1    Chicken Salad Bowl
#
#                                      choice_description item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# ...

# %%
df['choice_description']=df.choice_description.str.replace('[',' ').str.replace(']',' ')

# df.choice_description.str.replace('[\[\]]',' ')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# # Change the datatype in pandas(astype())

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
#convert Beeri_serving to fload
drinks['beer_servings']=drinks.beer_servings.astype(float)

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0                0              0
# 1        Albania           89.0              132             54
# 2        Algeria           25.0                0             14
# 3        Andorra          245.0              138            312
# 4         Angola          217.0               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0              100              3
# 189      Vietnam          111.0                2              1
# 190        Yemen            6.0                0              0
# 191       Zambia           32.0               19              4
# 192     Zimbabwe           64.0               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %% [markdown]
# ## How to define type of each column before actually reading the csv?Before Reading (During Reading time)

# %%
drinks= pd.read_csv('https://bit.ly/drinksbycountry',dtype={'beer_servings':float})

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# # Question?? In My dataset there is one column which label price which is type of 'OBJECT' and i want to do calculation on it . So what can i do?
#
# ## Ans. Convert datatype to Int/Float
#
# ## df.item_price.str.replace('\\$',"").astype(float).mean()

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                        Clementine      $3.39
# 2                                             Apple      $3.39
# 3                                                NaN     $2.39
# 4   Tomatillo-Red Chili Salsa (Hot),  Black Beans...    $16.98

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df['item_price']=df.item_price.str.replace('$',"")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      2.39
# ...

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df['item_price'] = df.item_price.astype(float)

# %%
df.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
df.sort_values('item_price')
# Out:
#       order_id  quantity                     item_name  \
# 1140       471         1                 Bottled Water
# 821        338         1                   Canned Soda
# 3926      1575         1                   Canned Soda
# 107         47         1                   Canned Soda
# 2562      1014         1                   Canned Soda
# ...        ...       ...                           ...
# 3601      1443         3                Veggie Burrito
# 3602      1443         4               Chicken Burrito
# 1254       511         4               Chicken Burrito
# 3480      1398         3                 Carnitas Bowl
# 3598      1443        15  Chips and Fresh Tomato Salsa
#
#                                      choice_description  item_price
# 1140                                                NaN        1.09
# 821                                          Coca Cola         1.09
# 3926                                        Dr. Pepper         1.09
# ...

# %% [markdown]
# ## I want to check if there is "Chicken" in dataset and convert from boolean result to int.

# %%
df.item_name.str.contains('Chicken').head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: item_name, dtype: bool

# %%
df.item_name.str.contains('Chicken').astype(int).head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: item_name, dtype: int32

# %% [markdown]
# # Groupby in pandas

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0                0              0
# 1        Albania           89.0              132             54
# 2        Algeria           25.0                0             14
# 3        Andorra          245.0              138            312
# 4         Angola          217.0               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0              100              3
# 189      Vietnam          111.0                2              1
# 190        Yemen            6.0                0              0
# 191       Zambia           32.0               19              4
# 192     Zimbabwe           64.0               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %% [markdown]
# ## What is the average beer servings across all country GROUPBY continent

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks[drinks.continent == 'Africa'].beer_servings.mean()
# Out:
# 61.471698113207545

# %% [markdown]
# ## When to use(GROUPBY)?Analyze panda "series"(Column) by Category

# %% [markdown]
# # Pro Tips
# ## (1) agg() function (Aggregator of all functions)
# ## (2) If we do not specify which column we want then pandas will count for all cols

# %%
drinks.groupby('continent').beer_servings.agg(['count','min','max','mean'])
# Out:
#                count   min    max        mean
# continent
# Africa            53   0.0  376.0   61.471698
# Asia              44   0.0  247.0   37.045455
# Europe            45   0.0  361.0  193.777778
# North America     23   1.0  285.0  145.434783
# Oceania           16   0.0  306.0   89.687500
# South America     12  93.0  333.0  175.083333

# %%
drinks.groupby('continent').mean()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
# %matplotlib inline

# %%
drinks.groupby('continent').mean().plot(kind="bar")

# %% [markdown]
# # Date And Time in pandas

# %%
ufo.head()
# Out:
#   colors__reported Shape__Reported state             time
# 0              NaN        TRIANGLE    NY   6/1/1930 22:00
# 3              NaN            DISK    KS   6/1/1931 13:00
# 4              NaN           LIGHT    NY  4/18/1933 19:00
# 5              NaN            DISK    ND  9/15/1934 15:30
# 6              NaN          CIRCLE    CA   6/15/1935 0:00

# %%
 ufo.dtypes
# Out:
# colors__reported    object
# Shape__Reported     object
# state               object
# time                object
# dtype: object

# %%
ufo.time.str.slice(-5,-3).astype(int).head()
# Out:
# 0    22
# 3    13
# 4    19
# 5    15
# 6     0
# Name: time, dtype: int32

# %%
ufo['time'] = pd.to_datetime(ufo.time)

# %%
ufo.head()
# Out:
#   colors__reported Shape__Reported state                time
# 0              NaN        TRIANGLE    NY 1930-06-01 22:00:00
# 3              NaN            DISK    KS 1931-06-01 13:00:00
# 4              NaN           LIGHT    NY 1933-04-18 19:00:00
# 5              NaN            DISK    ND 1934-09-15 15:30:00
# 6              NaN          CIRCLE    CA 1935-06-15 00:00:00

# %%
ufo.dtypes
# Out:
# colors__reported            object
# Shape__Reported             object
# state                       object
# time                datetime64[ns]
# dtype: object

# %%
ufo.time.dt.hour
# Out:
# 0        22
# 3        13
# 4        19
# 5        15
# 6         0
#          ..
# 18236    23
# 18237    23
# 18238    23
# 18239    23
# 18240    23
# Name: time, Length: 18239, dtype: int64

# %%
ufo.time.dt.weekday_name
# Out:
# 0          Sunday
# 3          Monday
# 4         Tuesday
# 5        Saturday
# 6        Saturday
#            ...
# 18236      Sunday
# 18237      Sunday
# 18238      Sunday
# 18239      Sunday
# 18240      Sunday
# Name: time, Length: 18239, dtype: object

# %%
ufo.time.dt.weekday
# Out:
# 0        6
# 3        0
# 4        1
# 5        5
# 6        5
#         ..
# 18236    6
# 18237    6
# 18238    6
# 18239    6
# 18240    6
# Name: time, Length: 18239, dtype: int64

# %%
pd.to_datetime('1/1/1999')
# Out:
# Timestamp('1999-01-01 00:00:00')

# %%
pd.to_datetime('30/3/1999')
# Out:
# Timestamp('1999-03-30 00:00:00')

# %%
tr = pd.to_datetime('3/30/1999')

# %%
ufo.loc[ufo.time > tr].head()
# Out:
#       colors__reported Shape__Reported state                time
# 13253              NaN          SPHERE    GA 1999-03-30 14:30:00
# 13254        RED GREEN           LIGHT    PA 1999-03-30 19:30:00
# 13255              RED            CONE    PA 1999-03-30 20:23:00
# 13256              NaN            DISK    CT 1999-03-30 21:00:00
# 13257            GREEN        FIREBALL    WA 1999-03-30 21:08:00

# %%
ufo.time.max()
# Out:
# Timestamp('2000-12-31 23:59:00')

# %%
op = ufo.time.max() - ufo.time.min()
op
# Out:
# Timedelta('25781 days 01:59:00')

# %%
op.days
# Out:
# 25781

# %%
# %matplotlib inline

# %%
ufo['Year'] = ufo.time.dt.year

# %%
ufo.head()
# Out:
#   colors__reported Shape__Reported state                time  Year
# 0              NaN        TRIANGLE    NY 1930-06-01 22:00:00  1930
# 3              NaN            DISK    KS 1931-06-01 13:00:00  1931
# 4              NaN           LIGHT    NY 1933-04-18 19:00:00  1933
# 5              NaN            DISK    ND 1934-09-15 15:30:00  1934
# 6              NaN          CIRCLE    CA 1935-06-15 00:00:00  1935

# %% [markdown]
# ## UFO signs report by year

# %%
ufo.Year.value_counts().sort_index().plot()

# %% [markdown]
# # Explore pandas series

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.genre.describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
movies.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
movies.genre.value_counts(normalize=True)
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Sci-Fi       0.005107
# Thriller     0.005107
# Film-Noir    0.003064
# Family       0.002043
# Fantasy      0.001021
# History      0.001021
# Name: genre, dtype: float64

# %%
movies.genre.value_counts(normalize=True).head()
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Name: genre, dtype: float64

# %%
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies.genre.nunique()
# Out:
# 16

# %%
pd.crosstab(movies.genre , movies.content_rating)
# Out:
# content_rating  APPROVED   G  GP  NC-17  NOT RATED  PASSED  PG  PG-13    R  \
# genre
# Action                 3   1   1      0          4       1  11     44   67
# Adventure              3   2   0      0          5       1  21     23   17
# Animation              3  20   0      0          3       0  25      5    5
# Biography              1   2   1      0          1       0   6     29   36
# Comedy                 9   2   1      1         16       3  23     23   73
# Crime                  6   0   0      1          7       1   6      4   87
# Drama                 12   3   0      4         24       1  25     55  143
# Family                 0   1   0      0          0       0   1      0    0
# Fantasy                0   0   0      0          0       0   0      0    1
# Film-Noir              1   0   0      0          1       0   0      0    0
# History                0   0   0      0          0       0   0      0    0
# ...

# %%
movies.duration.describe()
# Out:
# count    979.000000
# mean     120.979571
# std       26.218010
# min       64.000000
# 25%      102.000000
# 50%      117.000000
# 75%      134.000000
# max      242.000000
# Name: duration, dtype: float64

# %%
movies.duration.value_counts()
# Out:
# 112    23
# 113    22
# 102    20
# 101    20
# 129    19
#        ..
# 180     1
# 177     1
# 168     1
# 166     1
# 64      1
# Name: duration, Length: 133, dtype: int64

# %%
# %matplotlib inline

# %%
movies.duration.plot(kind = 'hist')

# %%
movies.genre.value_counts().plot(kind = 'bar')

# %% [markdown]
# # How do i handle missing values in pandas?

# %%
ufo.tail()
# Out:
#       colors__reported Shape__Reported state                time  Year
# 18236              NaN        TRIANGLE    IL 2000-12-31 23:00:00  2000
# 18237              NaN            DISK    IA 2000-12-31 23:00:00  2000
# 18238              NaN             NaN    WI 2000-12-31 23:45:00  2000
# 18239              RED           LIGHT    WI 2000-12-31 23:45:00  2000
# 18240              NaN            OVAL    FL 2000-12-31 23:59:00  2000

# %%
ufo.isnull().tail()
# Out:
#        colors__reported  Shape__Reported  state   time   Year
# 18236              True            False  False  False  False
# 18237              True            False  False  False  False
# 18238              True             True  False  False  False
# 18239             False            False  False  False  False
# 18240              True            False  False  False  False

# %%
ufo.notnull().tail()
# Out:
#        colors__reported  Shape__Reported  state  time  Year
# 18236             False             True   True  True  True
# 18237             False             True   True  True  True
# 18238             False            False   True  True  True
# 18239              True             True   True  True  True
# 18240             False             True   True  True  True

# %% [markdown]
# ## COunt how many NaN in Dataset

# %%
ufo = pd.read_csv('https://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.isnull().sum(axis=0)
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
#Boolean no sum kare etle Je True=1 ave and False=0
pd.Series([True,False,True]).sum()
# Out:
# 2

# %%
ufo[ufo.City.isnull()]
# Out:
#       City Colors Reported Shape Reported State              Time
# 21     NaN             NaN            NaN    LA    8/15/1943 0:00
# 22     NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 204    NaN             NaN           DISK    CA   7/15/1952 12:30
# 241    NaN            BLUE           DISK    MT    7/4/1953 14:00
# 613    NaN             NaN           DISK    NV    7/1/1960 12:00
# 1877   NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 2013   NaN             NaN            NaN    NH     8/1/1970 9:30
# 2546   NaN             NaN       FIREBALL    OH  10/25/1973 23:30
# 3123   NaN             RED       TRIANGLE    WV  11/25/1975 23:00
# 4736   NaN             NaN         SPHERE    CA   6/23/1982 23:00
# 5269   NaN             NaN            NaN    AZ   6/30/1985 21:30
# 6735   NaN             NaN      FORMATION    TX     4/1/1992 2:00
# 7208   NaN             NaN         CIRCLE    MI   10/4/1993 17:30
# ...

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
#Drop rows if any of the value is missing
ufo.dropna(how = 'any').shape
# Out:
# (2486, 5)

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
#only drop row who's all values are missing
ufo.dropna(how = 'all').shape
# Out:
# (18241, 5)

# %% [markdown]
# ## Drop a row either Shape_reported OR Color_reported values are missing.

# %%
ufo.dropna(subset = ['City', 'Shape Reported'],how = 'any')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18234              Capitola             NaN       TRIANGLE    CA
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %% [markdown]
# ## Drop a row either Shape_reported AND Color_reported values are missing.

# %%
ufo.dropna(subset = ['City', 'Shape Reported'],how = 'all')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %% [markdown]
# ## PRo TIp= FILLING MISSING VALUES

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# DOME            1
# HEXAGON         1
# FLARE           1
# PYRAMID         1
# Name: Shape Reported, dtype: int64

# %%
ufo['Shape Reported'].value_counts(dropna = False)
# Out:
# LIGHT        2803
# NaN          2644
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# PYRAMID         1
# FLARE           1
# DOME            1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
ufo['Shape Reported'].fillna(value = 'VARIOUS', inplace= True)

# %%
ufo['Shape Reported'].value_counts(dropna = False)
# Out:
# VARIOUS      2977
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# DOME            1
# HEXAGON         1
# FLARE           1
# PYRAMID         1
# Name: Shape Reported, dtype: int64

# %% [markdown]
# # Index

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.columns = drinks.columns.str.replace(' ',"_")

# %%
drinks.columns.str.upper()
# Out:
# Index(['COUNTRY', 'BEER_SERVINGS', 'SPIRIT_SERVINGS', 'WINE_SERVINGS',
#        'TOTAL_LITRES_OF_PURE_ALCOHOL', 'CONTINENT'],
#       dtype='object')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
drinks.shape
# Out:
# (193, 6)

# %%
movies = pd.read_csv("https://bit.ly/movieusers",header = None, sep = '|')

# %%
movies.head()
# Out:
#    0   1  2           3      4
# 0  1  24  M  technician  85711
# 1  2  53  F       other  94043
# 2  3  23  M      writer  32067
# 3  4  24  M  technician  43537
# 4  5  33  F       other  15213

# %%
drinks[drinks.continent == 'South America']
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 6    Argentina          193.0               25            221
# 20     Bolivia          167.0               41              8
# 23      Brazil          245.0              145             16
# 35       Chile          130.0              124            172
# 37    Colombia          159.0               76              3
# 52     Ecuador          162.0               74              3
# 72      Guyana           93.0              302              1
# 132   Paraguay          213.0              117             74
# 133       Peru          163.0              160             21
# 163   Suriname          128.0              178              7
# 185    Uruguay          115.0               35            220
# 188  Venezuela          333.0              100              3
#
#      total_litres_of_pure_alcohol      continent
# 6                             8.3  South America
# 20                            3.8  South America
# ...

# %% [markdown]
# ## Selection "loc[  ]"

# %%
drinks.loc[23, 'beer_servings']
# Out:
# 245.0

# %%
drinks.set_index('country',inplace = True)
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan            0.0                0              0
# Albania               89.0              132             54
# Algeria               25.0                0             14
# Andorra              245.0              138            312
# Angola               217.0               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua & Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Tanzania', 'USA', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela',
#        'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=193)

# %%
drinks.columns
# Out:
# Index(['beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.shape
# Out:
# (193, 5)

# %%
drinks.loc['Brazil', 'beer_servings']
# Out:
# 245.0

# %%
drinks.index.name = None

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan            0.0                0              0
# Albania               89.0              132             54
# Algeria               25.0                0             14
# Andorra              245.0              138            312
# Angola               217.0               57             45
#
#              total_litres_of_pure_alcohol continent
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.index.name = 'country'

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan            0.0                0              0
# Albania               89.0              132             54
# Algeria               25.0                0             14
# Andorra              245.0              138            312
# Angola               217.0               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.reset_index(inplace = True)
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.describe().index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
drinks.describe().columns
# Out:
# Index(['beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol'],
#       dtype='object')

# %%
drinks.describe().loc['25%','beer_servings']
# Out:
# 20.0

# %% [markdown]
# # Use Of "Inplace" Parameter

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.drop('City',axis=1).head()
# Out:
#   Colors Reported Shape Reported State             Time
# 0             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1             NaN          OTHER    NJ  6/30/1930 20:00
# 2             NaN           OVAL    CO  2/15/1931 14:00
# 3             NaN           DISK    KS   6/1/1931 13:00
# 4             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.drop('City',axis=1,inplace=True)

# %%
ufo.head()
# Out:
#   Colors Reported Shape Reported State             Time
# 0             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1             NaN          OTHER    NJ  6/30/1930 20:00
# 2             NaN           OVAL    CO  2/15/1931 14:00
# 3             NaN           DISK    KS   6/1/1931 13:00
# 4             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.shape
# Out:
# (18241, 4)

# %%
ufo.dropna(how = 'any',axis=0)
# Out:
#       Colors Reported Shape Reported State              Time
# 12                RED         SPHERE    SC   6/30/1939 20:00
# 19                RED          OTHER    AK   4/30/1943 23:00
# 36                RED      FORMATION    VA    7/10/1945 1:30
# 44              GREEN         SPHERE    CA   6/30/1946 19:00
# 66               BLUE        VARIOUS    PA    7/1/1947 20:00
# ...               ...            ...   ...               ...
# 18213           GREEN       FIREBALL    CA  12/28/2000 19:10
# 18216          ORANGE          LIGHT    CA  12/29/2000 16:10
# 18220            BLUE           DISK    CA  12/29/2000 20:30
# 18233             RED        VARIOUS    AK  12/31/2000 21:00
# 18239             RED          LIGHT    WI  12/31/2000 23:45
#
# [2882 rows x 4 columns]

# %%
ufo = ufo.set_index('Time') #Navo dataframe ma data store kare che
#ufo.set_index('Time',inplace = True) ama Evu Nathi Karto

# %%
ufo.tail()
# Out:
#                  Colors Reported Shape Reported State
# Time
# 12/31/2000 23:00             NaN       TRIANGLE    IL
# 12/31/2000 23:00             NaN           DISK    IA
# 12/31/2000 23:45             NaN        VARIOUS    WI
# 12/31/2000 23:45             RED          LIGHT    WI
# 12/31/2000 23:59             NaN           OVAL    FL

# %%
ufo.fillna(method = 'ffill').tail()
# Out:
#                  Colors Reported Shape Reported State
# Time
# 12/31/2000 23:00             RED       TRIANGLE    IL
# 12/31/2000 23:00             RED           DISK    IA
# 12/31/2000 23:45             RED        VARIOUS    WI
# 12/31/2000 23:45             RED          LIGHT    WI
# 12/31/2000 23:59             RED           OVAL    FL
